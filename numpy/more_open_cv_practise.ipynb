# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
image = cv2.imread("data/portrait.jpg", 1)
print(type(image))
print(image.shape)

plt.imshow(image[:, :, [2, 1, 0]])
# Out:
# <class 'numpy.ndarray'>
# (1080, 1920, 3)

# %%
bg = cv2.imread("data/background.jpg")
plt.imshow(bg[:,:,::-1])

# %%
new_bg = cv2.imread("data/shibameme.jpg")
new_bg = cv2.resize(new_bg, (1920, 1080))
plt.imshow(new_bg[:,:, [2,1,0]])

# %%
diff = cv2.absdiff(bg, image)

_, diff_display = cv2.threshold(diff.astype(np.uint8), 15, 255, cv2.THRESH_BINARY)
